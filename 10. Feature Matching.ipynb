# %% [markdown]
# # OpenCV Tutorial

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_1 = cv2.imread(r'D:\hrutik\Wallpapers\DIP\p9.jpg', 0)
img_2 = cv2.imread(r'D:\hrutik\Wallpapers\DIP\p10.jpg', 0)

cv2.imshow('image', img_2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
orb = cv2.ORB_create()

#key points and descriptors

kp1, des1 = orb.detectAndCompute(img_1, None)
kp2, des2 = orb.detectAndCompute(img_2, None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

matches = bf.match(des1, des2)
matches = sorted(matches, key=lambda x:x.distance)

img_3 = cv2.drawMatches(img_1, kp1, img_2, kp2, matches[:10], None, flags=2)
plt.imshow(img_3)
plt.show()
